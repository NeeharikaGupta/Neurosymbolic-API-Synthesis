# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# %%
def get_model_urls(pages=1):
    base_url = "https://huggingface.co/models"
    urls = []

    for page in range(1, pages + 1):
        res = requests.get(f"{base_url}?p={page}")
        soup = BeautifulSoup(res.content, "html.parser")

        for a in soup.find_all("a", href=True):
            href = a["href"]
            if href.startswith("/") and len(href.split("/")) == 3:
                urls.append("https://huggingface.co" + href)

        time.sleep(1)

    return list(set(urls))  # deduplicate

def scrape_model_page(url):
    try:
        res = requests.get(url)
        soup = BeautifulSoup(res.content, "html.parser")
        title = soup.find("h1").text.strip() if soup.find("h1") else url.split("/")[-1]

        code_blocks = []
        for pre in soup.find_all("pre"):
            code = pre.text.strip()
            if any(kw in code for kw in ["from transformers", "pipeline", "AutoModel", "AutoTokenizer"]):
                code_blocks.append(code)

        if code_blocks:
            return {
                "url": url,
                "title": title,
                "code_snippets": code_blocks
            }
        else:
            return None
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

def scrape_huggingface_models(max_pages=1):
    model_urls = get_model_urls(pages=max_pages)
    print(f"Found {len(model_urls)} model pages.")

    data = []
    for url in model_urls:
        print(f"Scraping: {url}")
        item = scrape_model_page(url)
        if item:
            data.append(item)
        time.sleep(1.2)

    return data

def save_to_json(data, filename):
    with open(filename, "w") as f:
        json.dump(data, f, indent=2)
    print(f"Saved {len(data)} entries to {filename}")

# %%
hf_data = scrape_huggingface_models(max_pages=2)
save_to_json(hf_data, "huggingface_models.json")
# Out:
# Found 61 model pages.
# Scraping: https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct
# Scraping: https://huggingface.co/google/gemma-3-27b-it
# Scraping: https://huggingface.co/black-forest-labs/FLUX.1-schnell
# Scraping: https://huggingface.co/google/gemma-3-1b-it
# Scraping: https://huggingface.co/Qwen/Qwen3-0.6B
# Scraping: https://huggingface.co/ds4sd/SmolDocling-256M-preview
# Scraping: https://huggingface.co/tiiuae/Falcon-H1-34B-Instruct
# Scraping: https://huggingface.co/BAAI/bge-m3
# Scraping: https://huggingface.co/TheDrummer/Valkyrie-49B-v1
# Scraping: https://huggingface.co/deepseek-ai/DeepSeek-V3-0324
# Scraping: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503
# Scraping: https://huggingface.co/a-m-team/AM-Thinking-v1
# Scraping: https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3
# Scraping: https://huggingface.co/stabilityai/stable-diffusion-3.5-large
# Scraping: https://huggingface.co/BLIP3o/BLIP3o-Model-8B
# Scraping: https://huggingface.co/aleksa-codes/flux-ghibsky-illustration
# Scraping: https://huggingface.co/facebook/UMA
# Scraping: https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2
# Scraping: https://huggingface.co/mistralai/Devstral-Small-2505_gguf
# Scraping: https://huggingface.co/Gapeleon/bytedance_BAGEL-7B-MoT-INT8
# Scraping: https://huggingface.co/coqui/XTTS-v2
# Scraping: https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0
# Scraping: https://huggingface.co/Intelligent-Internet/II-Medical-8B
# Scraping: https://huggingface.co/GSAI-ML/LLaDA-8B-Instruct
# Scraping: https://huggingface.co/OuteAI/OuteTTS-1.0-0.6B
# Scraping: https://huggingface.co/Wan-AI/Wan2.1-VACE-1.3B
# Scraping: https://huggingface.co/litert-community/Gemma3-1B-IT
# Scraping: https://huggingface.co/Qwen/Qwen3-4B
# Scraping: https://huggingface.co/Tongyi-Zhiwen/QwenLong-L1-32B
# Scraping: https://huggingface.co/yanboding/MTVCrafter
# Scraping: https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct
# Scraping: https://huggingface.co/Qwen/Qwen3-30B-A3B
# Scraping: https://huggingface.co/PocketDoc/Dans-PersonalityEngine-V1.3.0-24b
# Scraping: https://huggingface.co/Qwen/Qwen3-8B
# Scraping: https://huggingface.co/Kijai/WanVideo_comfy
# Scraping: https://huggingface.co/lmstudio-community/Devstral-Small-2505-GGUF
# Scraping: https://huggingface.co/google/gemma-3-4b-it
# Scraping: https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged
# Scraping: https://huggingface.co/sesame/csm-1b
# Scraping: https://huggingface.co/Qwen/Qwen3-32B
# Scraping: https://huggingface.co/stabilityai/sv4d2.0
# Scraping: https://huggingface.co/silveroxides/Chroma-GGUF
# Scraping: https://huggingface.co/jinaai/jina-embeddings-v3
# Scraping: https://huggingface.co/openai/whisper-large-v3
# Scraping: https://huggingface.co/unsloth/medgemma-27b-text-it-GGUF
# Scraping: https://huggingface.co/DMindAI/DMind-1
# Scraping: https://huggingface.co/fancyfeast/llama-joycaption-beta-one-hf-llava
# Scraping: https://huggingface.co/search/full-text?type=model
# Scraping: https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5
# Scraping: https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
# Scraping: https://huggingface.co/facebook/OMol25
# Scraping: https://huggingface.co/ZuluVision/MoviiGen1.1
# Scraping: https://huggingface.co/pyannote/speaker-diarization-3.1
# Scraping: https://huggingface.co/ACE-Step/ACE-Step-v1-3.5B
# Scraping: https://huggingface.co/scb10x/typhoon-ocr-7b
# Scraping: https://huggingface.co/kakaocorp/kanana-1.5-8b-instruct-2505
# Scraping: https://huggingface.co/TEN-framework/ten-vad
# Scraping: https://huggingface.co/moondream/moondream-2b-2025-04-14-4bit
# Scraping: https://huggingface.co/stepfun-ai/Step1X-3D
# Scraping: https://huggingface.co/tencent/Hunyuan3D-2
# Scraping: https://huggingface.co/stabilityai/stable-audio-open-small
# Saved 29 entries to huggingface_models.json
