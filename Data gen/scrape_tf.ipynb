# %%
import requests
from bs4 import BeautifulSoup
import time
import json

# %%
BASE_URL = "https://www.tensorflow.org/tutorials"
HEADERS = {"User-Agent": "Mozilla/5.0"}

# %%
def get_tutorial_links():
    res = requests.get(BASE_URL, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")
    links = []
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if href.startswith("/tutorials/") and "overview" not in href:
            full_url = "https://www.tensorflow.org" + href
            links.append(full_url)
    return list(set(links))

# %%
def scrape_tutorial(url):
    res = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")
    title = soup.find("h1").text.strip() if soup.find("h1") else ""

    code_snippets = []
    for pre in soup.find_all("pre"):
        code_block = pre.text.strip()
        # Keep only likely Python code
        if any(code_block.startswith(kw) for kw in ("import", "def", "class")) or "tf." in code_block:
            code_snippets.append(code_block)

    return {
        "url": url,
        "title": title,
        "code_snippets": code_snippets
    }

# %%
def scrape_all_tutorials():
    tutorial_links = get_tutorial_links()
    all_data = []
    for link in tutorial_links:
        print(f"Scraping: {link}")
        data = scrape_tutorial(link)
        all_data.append(data)
        time.sleep(1.5)
    return all_data

# %%
def scrape_tensorflow():
    base_url = "https://www.tensorflow.org/tutorials"
    res = requests.get(base_url, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")

    links = {
        "https://www.tensorflow.org" + a["href"]
        for a in soup.find_all("a", href=True)
        if a["href"].startswith("/tutorials/") and "overview" not in a["href"]
    }

    data = []
    for url in links:
        res = requests.get(url, headers=HEADERS)
        page = BeautifulSoup(res.content, "html.parser")
        title = page.find("h1").text.strip() if page.find("h1") else ""
        code_blocks = [pre.text.strip() for pre in page.find_all("pre") if "tf." in pre.text or pre.text.strip().startswith(("import", "def", "class"))]
        data.append({"url": url, "title": title, "code_snippets": code_blocks})
        time.sleep(1.2)
    return data

# %%
tutorials = scrape_all_tutorials()
with open("tensorflow_tutorials.json", "w") as f:
    json.dump(tutorials, f, indent=2)
print(f"Scraped {len(tutorials)} tutorials.")
# Out:
# Scraping: https://www.tensorflow.org/tutorials/generative/pix2pix
# Scraping: https://www.tensorflow.org/tutorials/keras/text_classification_with_hub
# Scraping: https://www.tensorflow.org/tutorials/keras/classification
# Scraping: https://www.tensorflow.org/tutorials/load_data/text
# Scraping: https://www.tensorflow.org/tutorials/keras/overfit_and_underfit
# Scraping: https://www.tensorflow.org/tutorials/distribute/save_and_load
# Scraping: https://www.tensorflow.org/tutorials/video/transfer_learning_with_movinet
# Scraping: https://www.tensorflow.org/tutorials/distribute/dtensor_keras_tutorial
# Scraping: https://www.tensorflow.org/tutorials/generative/cyclegan
# Scraping: https://www.tensorflow.org/tutorials/generative/dcgan
# Scraping: https://www.tensorflow.org/tutorials/distribute/parameter_server_training
# Scraping: https://www.tensorflow.org/tutorials/generative/autoencoder
# Scraping: https://www.tensorflow.org/tutorials/keras/text_classification
# Scraping: https://www.tensorflow.org/tutorials/optimization/compression
# Scraping: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_ctl
# Scraping: https://www.tensorflow.org/tutorials/customization/custom_training_walkthrough
# Scraping: https://www.tensorflow.org/tutorials/quickstart/beginner
# Scraping: https://www.tensorflow.org/tutorials/video/video_classification
# Scraping: https://www.tensorflow.org/tutorials/text
# Scraping: https://www.tensorflow.org/tutorials/load_data/images
# Scraping: https://www.tensorflow.org/tutorials/generative/style_transfer
# Scraping: https://www.tensorflow.org/tutorials/generative/cvae
# Scraping: https://www.tensorflow.org/tutorials/distribute/input
# Scraping: https://www.tensorflow.org/tutorials/generative/data_compression
# Scraping: https://www.tensorflow.org/tutorials/images/transfer_learning
# Scraping: https://www.tensorflow.org/tutorials/load_data/tfrecord
# Scraping: https://www.tensorflow.org/tutorials/load_data/numpy
# Scraping: https://www.tensorflow.org/tutorials/load_data/video
# Scraping: https://www.tensorflow.org/tutorials/distribute/keras
# Scraping: https://www.tensorflow.org/tutorials/audio/music_generation
# Scraping: https://www.tensorflow.org/tutorials/estimator/premade
# Scraping: https://www.tensorflow.org/tutorials/generative/adversarial_fgsm
# Scraping: https://www.tensorflow.org/tutorials/customization/basics
# Scraping: https://www.tensorflow.org/tutorials/structured_data/time_series
# Scraping: https://www.tensorflow.org/tutorials/generative/generate_images_with_stable_diffusion
# Scraping: https://www.tensorflow.org/tutorials/interpretability/integrated_gradients
# Scraping: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_keras
# Scraping: https://www.tensorflow.org/tutorials/load_data/pandas_dataframe
# Scraping: https://www.tensorflow.org/tutorials/images/transfer_learning_with_hub
# Scraping: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_estimator
# Scraping: https://www.tensorflow.org/tutorials/distribute/custom_training
# Scraping: https://www.tensorflow.org/tutorials/quickstart/advanced
# Scraping: https://www.tensorflow.org/tutorials/images/classification
# Scraping: https://www.tensorflow.org/tutorials/audio/transfer_learning_audio
# Scraping: https://www.tensorflow.org/tutorials/reinforcement_learning/actor_critic
# Scraping: https://www.tensorflow.org/tutorials/keras/save_and_load
# Scraping: https://www.tensorflow.org/tutorials/keras/regression
# Scraping: https://www.tensorflow.org/tutorials/images
# Scraping: https://www.tensorflow.org/tutorials/audio/simple_audio
# Scraping: https://www.tensorflow.org/tutorials/distribute/dtensor_ml_tutorial
# Scraping: https://www.tensorflow.org/tutorials/keras/keras_tuner
# Scraping: https://www.tensorflow.org/tutorials/images/cnn
# Scraping: https://www.tensorflow.org/tutorials/structured_data/preprocessing_layers
# Scraping: https://www.tensorflow.org/tutorials/structured_data/imbalanced_data
# Scraping: https://www.tensorflow.org/tutorials/understanding/sngp
# Scraping: https://www.tensorflow.org/tutorials/estimator/linear
# Scraping: https://www.tensorflow.org/tutorials/text/nmt_with_attention
# Scraping: https://www.tensorflow.org/tutorials/estimator/keras_model_to_estimator
# Scraping: https://www.tensorflow.org/tutorials/generative/deepdream
# Scraping: https://www.tensorflow.org/tutorials/images/segmentation
# Scraping: https://www.tensorflow.org/tutorials/images/data_augmentation
# Scraping: https://www.tensorflow.org/tutorials/customization/custom_layers
# Scraping: https://www.tensorflow.org/tutorials/structured_data/feature_columns
# Scraping: https://www.tensorflow.org/tutorials/text/transformer
# Scraping: https://www.tensorflow.org/tutorials/load_data/csv
# Scraped 65 tutorials.
